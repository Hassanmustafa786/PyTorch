# %% [markdown]
# # Building Networks Easily with Sequential Models in PyTorch

# %%
import torch
import torch.nn as nn

# Creating a basic sequential model
model = nn.Sequential(
    nn.Linear(2, 5),    # First layer: input size 2, output size 5
    nn.ReLU(),           # ReLU activation function
    nn.Linear(5, 1),   # Second layer: input size 5, output size 1
    nn.Sigmoid()         # Sigmoid activation function
)

# Print model's architecture
print("Sequential Model Architecture:\n", model)

# %% [markdown]
# Now that you're comfortable constructing sequential neural networks with multiple layers and activation functions, it's time to cement that knowledge with a follow-up task. Add to the provided model an extra hidden layer with 7 inputs and 10 outputs, followed by a ReLU activation function. Place it between the existing ones and do not forget to modify the next layer to work with the new one.

# %%
import torch
import torch.nn as nn

# Original Sequential Model
model = nn.Sequential(
    nn.Linear(2, 7),   # First layer - input size 2, output size 7
    nn.ReLU(),         # ReLU activation function

   # TODO: Add another layer to the model (7 inputs, 10 outputs) followed by ReLU function
    nn.Linear(7, 10),  # Another layer - input size 7, output size 10
    nn.ReLU(),         # ReLU activation function

    nn.Linear(10, 1),  # Output layer - input size 10, output size 1
    nn.Sigmoid()       # Sigmoid activation function
)



# Print the model's architecture
print("Original Sequential Model Architecture:\n", model)

# %% [markdown]
# Congrats on running a Sequential Model in PyTorch! Now, let's solidify your understanding of this topic further. For this task, you are required to write a PyTorch Sequential model with three layers:
#
# 1. First layer: input size 3, output size 7, followed by ReLU.
# 2. Second layer: input size 7, output size 5, followed by ReLU.
# 3. Third layer: input size 5, output size 1, followed by Sigmoid.
#
# After constructing the model, print its architecture.

# %%
import torch
import torch.nn as nn

# TODO: Create your Sequential model here
model = nn.Sequential(
    nn.Linear(3, 7),      # First layer - input size 3, output size 7
    nn.ReLU(),           # ReLU activation function
    
    nn.Linear(7, 5),      # Second layer - input size 7, output size 5
    nn.ReLU(),           # ReLU activation function
    
    nn.Linear(5, 1),      # Third layer - input size 5, output size 1
    nn.Sigmoid()         # Sigmoid activation function
)
# TODO: Print the model's architecture here
print("Sequential Model Architecture:\n", model)
